# %%
import pykitti
import numpy as np

# %%
date = '2011_09_26'
drive = '0001'

# %%
data = pykitti.raw('./', date, drive)

# %%
y1 = data.get_velo(1)
point_cam0 = data.calib.T_cam2_velo

# %%
x = [[ 2.34773698e-04, -9.99944155e-01, -1.05634778e-02,
         5.93721868e-02],
       [ 1.04494074e-02,  1.05653536e-02, -9.99889574e-01,
        -7.51087914e-02],
       [ 9.99945389e-01,  1.24365378e-04,  1.04513030e-02,
        -2.72132796e-01],
       [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
         1.00000000e+00]]

# %%
x = np.array(x)
z = x.dot(y1[0])

# %%
np.save('./calibraion.npy', x)

# %%
np.save(x, './KITTI/calib.npy')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-df9cd8d3c12e> in <module>
# ----> 1 np.save(x, './KITTI/calib.npy')
#
# <__array_function__ internals> in save(*args, **kwargs)
#
# ~/anaconda3/envs/obj_detect/lib/python3.6/site-packages/numpy/lib/npyio.py in save(file, arr, allow_pickle, fix_imports)
#     536         fid = file
#     537     else:
# --> 538         file = os_fspath(file)
#     539         if not file.endswith('.npy'):
#     540             file = file + '.npy'
#
# TypeError: expected str, bytes or os.PathLike object, not numpy.ndarray

# %%
point_imu = np.array([0, 0, 0, 1])
point_w = [o.T_w_imu.dot(point_imu) for o in data.oxts]

# %%
cam2_image, cam3_image = data.get_rgb(3)

# %%
for i in range(len(data)):
    y1 = data.get_velo(i)
    print('---------')
    print('xmin : {:.2f} // xmax: {:.2f} //'.format(np.min(y1[:, 0]), np.max(y1[:, 0])))
    print('ymin : {:.2f} // ymax: {:.2f} //'.format(np.min(y1[:, 1]), np.max(y1[:, 1])))
    print('zmin : {:.2f} // zmax: {:.2f} //'.format(np.min(y1[:, 2]), np.max(y1[:, 2])))
    print('---------')
# Out:
# ---------
# xmin : -78.52 // xmax: 78.67 //
# ymin : -34.78 // ymax: 73.11 //
# zmin : -4.97 // zmax: 2.87 //
# ---------
# ---------
# xmin : -79.14 // xmax: 78.19 //
# ymin : -33.95 // ymax: 73.12 //
# zmin : -14.44 // zmax: 2.84 //
# ---------
# ---------
# xmin : -78.20 // xmax: 76.61 //
# ymin : -33.33 // ymax: 64.13 //
# zmin : -14.88 // zmax: 2.79 //
# ---------
# ---------
# xmin : -78.11 // xmax: 76.64 //
# ymin : -33.35 // ymax: 64.14 //
# zmin : -15.30 // zmax: 2.78 //
# ---------
# ---------
# xmin : -78.46 // xmax: 76.32 //
# ymin : -34.53 // ymax: 61.18 //
# zmin : -15.73 // zmax: 2.83 //
# ---------
# ---------
# xmin : -78.65 // xmax: 78.25 //
# ymin : -33.72 // ymax: 58.28 //
# zmin : -5.29 // zmax: 2.82 //
# ---------
# ---------
# xmin : -78.65 // xmax: 79.19 //
# ymin : -33.81 // ymax: 55.50 //
# zmin : -5.30 // zmax: 2.91 //
# ---------
# ---------
# xmin : -78.27 // xmax: 78.68 //
# ymin : -33.11 // ymax: 79.27 //
# zmin : -5.30 // zmax: 2.91 //
# ---------
# ...

# %%
len(data)
# Out:
# 108

# %%
for i in x:
    print(i)
# Out:
# 10.941  2.853  0.   ]
#  [77.21  11.284  2.848  0.   ]
#  ...
#  [ 3.772 -1.42  -1.764  0.34 ]
#  [ 3.756 -1.407 -1.754  0.15 ]
#  [ 3.767 -1.398 -1.758  0.   ]]
# [[76.029 10.745  2.806  0.   ]
#  [76.044 10.991  2.807  0.   ]
#  [76.164 11.253  2.813  0.   ]
#  ...
#  [ 3.759 -1.415 -1.757  0.39 ]
#  [ 3.624 -1.351 -1.687  0.   ]
#  [ 3.781 -1.397 -1.764  0.   ]]
# [[74.531 11.131  2.757  0.   ]
#  [74.855 11.42   2.77   0.   ]
#  [74.805 11.653  2.769  0.   ]
#  ...
#  [ 3.731 -1.411 -1.744  0.36 ]
#  [ 3.69  -1.382 -1.721  0.   ]
#  [ 3.764 -1.397 -1.756  0.   ]]
# [[78.525  7.595  2.877  0.   ]
#  [78.604  7.852  2.88   0.   ]
#  [78.513  8.092  2.878  0.   ]
#  ...
#  [ 3.738 -1.42  -1.748  0.42 ]
#  [ 3.754 -1.413 -1.754  0.35 ]
#  [ 3.76  -1.402 -1.755  0.   ]]
# [[77.158  7.83   2.832  0.   ]
#  [77.431  8.103  2.842  0.   ]
#  [77.183  8.323  2.834  0.   ]
#  ...
#  [ 3.745 -1.417 -1.751  0.32 ]
#  [ 3.766 -1.411 -1.759  0.41 ]
#  [ 3.757 -1.394 -1.753  0.   ]]
# ...
